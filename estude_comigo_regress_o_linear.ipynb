# %% [markdown]
# <a href="https://colab.research.google.com/github/thallesrb/estude-comigo/blob/main/estude_comigo_regress_o_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estude comigo
#
# 100 horas de Machine Learning Clássico

# %% [markdown]
# Atualizado em 13/02/2026.
# Outra  versão.

# %%
import numpy as np
